# %%
nombre = "Erick"
print("Hola,", nombre)
# Out:
# Hola, Erick

# %% [markdown]
# #Mi primer notebook
#
# Estoy practicando Python con Jupyter

# %% [markdown]
# # Mi primer notebook
# Estoy practicando Pyhton con Jupyter
